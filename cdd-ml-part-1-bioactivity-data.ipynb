# %% [markdown]
# <a href="https://colab.research.google.com/gist/aghnisyaa/4fe621fc10db1700ff5d7e831f55369a/cdd-ml-part-1-bioactivity-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
#
# In this Jupyter notebook, I will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.10/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for dengue virus**

# %%
# Target search for dengue virus
target = new_client.target
target_query = target.search('dengue virus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 197                                                 []
# 198  [{'xref_id': 'Q69422', 'xref_name': None, 'xre...
# 199                                                 []
# 200                                                 []
# 201                                                 []
#
#                                               organism  \
# 0                                         Dengue virus
# 1                                  dengue virus type 4
# 2                                  dengue virus type 1
# 3                                  dengue virus type 2
# 4                                  dengue virus type 3
# ..                                                 ...
# 197  Human immunodeficiency virus type 1 (RF/HAT IS...
# 198                               Hepatitis GB virus B
# 199                                       Homo sapiens
# 200                                       Homo sapiens
# 201                                       Homo sapiens
#
#                                              pref_name  score  \
# 0                                         Dengue virus   24.0
# 1                                  dengue virus type 4   18.0
# 2                                  dengue virus type 1   18.0
# 3                                  dengue virus type 2   18.0
# 4                                  dengue virus type 3   18.0
# ..                                                 ...    ...
# 197  Human immunodeficiency virus type 1 (RF/HAT IS...    4.0
# 198  Hepatitis GB virus B NS5B RNA-dependent RNA po...    4.0
# 199    VEGF-receptor 2 and tyrosine-protein kinase SRC    4.0
# 200                                Sharpin/RBCK1/RNF31    4.0
# 201                                       80S Ribosome    0.0
#
#      species_group_flag target_chembl_id  \
# 0                 False     CHEMBL613757
# 1                 False     CHEMBL613728
# 2                 False     CHEMBL613360
# 3                 False     CHEMBL613966
# 4                 False     CHEMBL612717
# ..                  ...              ...
# 197               False     CHEMBL613498
# 198               False       CHEMBL5981
# 199               False    CHEMBL2111336
# 200               False    CHEMBL4296109
# 201               False    CHEMBL3987582
#
#                                      target_components  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 197                                                 []
# 198  [{'accession': 'Q69422', 'component_descriptio...
# 199  [{'accession': 'P12931', 'component_descriptio...
# 200  [{'accession': 'Q9H0F6', 'component_descriptio...
# 201  [{'accession': 'P08865', 'component_descriptio...
#
#                       target_type  tax_id
# 0                        ORGANISM   12637
# 1                        ORGANISM   11070
# 2                        ORGANISM   11053
# 3                        ORGANISM   11060
# 4                        ORGANISM   11069
# ..                            ...     ...
# 197                      ORGANISM   11701
# 198                SINGLE PROTEIN   39113
# 199             SELECTIVITY GROUP    9606
# 200               PROTEIN COMPLEX    9606
# 201  PROTEIN NUCLEIC-ACID COMPLEX    9606
#
# [202 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL612717'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#   action_type activity_comment  activity_id  \
# 0        None             None     12674455
# 1        None             None     18326333
# 2        None             None     19235373
# 3        None             None     19235452
# 4        None             None     19235453
# 5        None             None     19235470
# 6        None             None     19440701
# 7        None             None     24708214
# 8        None             None     24789044
# 9        None             None     24866747
#
#                                  activity_properties assay_chembl_id  \
# 0                                                 []   CHEMBL2341562
# 1                                                 []   CHEMBL4135359
# 2                                                 []   CHEMBL4398331
# 3                                                 []   CHEMBL4398397
# 4                                                 []   CHEMBL4398397
# 5                                                 []   CHEMBL4398414
# 6                                                 []   CHEMBL4431626
# 7  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5109272
# 8  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5131959
# 9  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5151807
#
#                                    assay_description assay_type  \
# 0  Antiviral activity against Dengue virus 3 stra...          F
# 1  Antiviral activity against Fluc-tagged DENV3 i...          F
# 2  Antiviral activity against DENV3 Bolivia infec...          F
# 3  Antiviral activity against DENV3 97 infected i...          F
# 4  Antiviral activity against DENV3 97 infected i...          F
# 5  Antiviral activity against DENV3 infected in h...          F
# 6  Antiviral activity against Dengue virus 3 infe...          F
# 7  Antiviral activity against DENV3 infected in A...          F
# 8  Antiviral activity against DENV 3 infected in ...          F
# 9  Antiviral activity against DENV-3 infected ham...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
# 3                    None                   None  BAO_0000190  ...
# 4                    None                   None  BAO_0000190  ...
# 5                    None                   None  BAO_0000190  ...
# 6                    None                   None  BAO_0000190  ...
# 7                    None                   None  BAO_0000190  ...
# 8                    None                   None  BAO_0000190  ...
# 9                    None                   None  BAO_0000190  ...
#
#        target_organism     target_pref_name target_tax_id text_value  toid  \
# 0  dengue virus type 3  dengue virus type 3         11069       None  None
# 1  dengue virus type 3  dengue virus type 3         11069       None  None
# 2  dengue virus type 3  dengue virus type 3         11069       None  None
# 3  dengue virus type 3  dengue virus type 3         11069       None  None
# 4  dengue virus type 3  dengue virus type 3         11069       None  None
# 5  dengue virus type 3  dengue virus type 3         11069       None  None
# 6  dengue virus type 3  dengue virus type 3         11069       None  None
# 7  dengue virus type 3  dengue virus type 3         11069       None  None
# 8  dengue virus type 3  dengue virus type 3         11069       None  None
# 9  dengue virus type 3  dengue virus type 3         11069       None  None
#
#    type units    uo_units upper_value  value
# 0  IC50    uM  UO_0000065        None  100.0
# 1  IC50    uM  UO_0000065        None   0.73
# 2  IC50    uM  UO_0000065        15.0    6.8
# 3  IC50    uM  UO_0000065        10.4    6.9
# 4  IC50    uM  UO_0000065        10.8    6.5
# 5  IC50    uM  UO_0000065        None  13.07
# 6  IC50    uM  UO_0000065         1.0    0.5
# 7  IC50    uM  UO_0000065        None    5.0
# 8  IC50    uM  UO_0000065        None    5.0
# 9  IC50    uM  UO_0000065        None   1.66
#
# [10 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google drive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !ls "/content/gdrive/My Drive/"

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 7
# -rw------- 1 root root 6768 Nov 24 13:09 bioactivity_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,12674455,[],CHEMBL2341562,Antiviral activity against Dengue virus 3 strain H87 in Vero cells assessed as inhibition of virus-induced cytopathogenicity after 4 to 6 days,F,,,BAO_0000190,BAO_0000218,organism-based format,O=C(CNCc1ccc(C(=O)N2CCCCC2)cc1)NC(=O)COc1ccccc1,,,CHEMBL2331182,Bioorg Med Chem Lett,2013,,CHEMBL2332247,,CHEMBL2332247,,0,http://www.openphacts.org/units/Nanomolar,1865876,>,1,1,>,,IC50,nM,,100000.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,,100.0
# ,,18326333,[],CHEMBL4135359,Antiviral activity against Fluc-tagged DENV3 infected in human HuH7 cells after 3 days by luciferase reporter gene assay,F,,,BAO_0000190,BAO_0000218,organism-based format,COc1ccc(-c2cc(-c3ccc4cc(F)ccc4n3)n(-c3ccc(S(N)(=O)=O)cc3)n2)cc1,,,CHEMBL4130503,Eur J Med Chem,2017,,CHEMBL4175102,,CHEMBL4175102,6.14,0,http://www.openphacts.org/units/Nanomolar,3042639,=,1,1,=,,IC50,nM,,730.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,,0.73
# ,,19235373,[],CHEMBL4398331,Antiviral activity against DENV3 Bolivia infected in African green monkey Vero E6 cells after 3 to 4 days by RT-PCR analysis,F,,,BAO_0000190,BAO_0000218,organism-based format,O=C(N[C@@H](Cc1ccc(O)cc1)C(=O)O)c1cc(-c2ccccc2)c(=O)n2c1sc1ccc(OC3CCCCC3)cc12,,,CHEMBL4396891,Eur J Med Chem,2019,,CHEMBL4526128,,CHEMBL4526128,5.17,0,http://www.openphacts.org/units/Nanomolar,3210829,=,1,1,=,,IC50,nM,,6800.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,15.0,6.8
# ,,19235452,[],CHEMBL4398397,Antiviral activity against DENV3 97 infected in human Huh7.5 cells after 72 hrs,F,,,BAO_0000190,BAO_0000218,organism-based format,CCCCCCCCCCCCNCCNC(=O)C[C@@]1(O)C[C@@H](O)[C@@H]2OC(C)(C)O[C@@H]2C1,,,CHEMBL4396891,Eur J Med Chem,2019,,CHEMBL4443913,,CHEMBL4443913,5.16,0,http://www.openphacts.org/units/Nanomolar,3210873,=,1,1,=,,IC50,nM,,6900.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,10.4,6.9
# ,,19235453,[],CHEMBL4398397,Antiviral activity against DENV3 97 infected in human Huh7.5 cells after 72 hrs,F,,,BAO_0000190,BAO_0000218,organism-based format,CCCCCCCCCCCCCCNCCNC(=O)C[C@]1(O)C[C@@H](O)[C@@H](O)[C@H](O)C1.Cl,,,CHEMBL4396891,Eur J Med Chem,2019,,CHEMBL4572441,,CHEMBL4595471,5.19,0,http://www.openphacts.org/units/Nanomolar,3210874,=,1,1,=,,IC50,nM,,6500.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,10.8,6.5
# ,,19235470,[],CHEMBL4398414,Antiviral activity against DENV3 infected in human Huh7 cells assessed as reduction in viral yield after 48 hrs by MTT assay,F,,,BAO_0000190,BAO_0000218,organism-based format,O=C1[C@H](CC[C@H](O)c2ccc(F)cc2)[C@@H](c2ccc(O)cc2)N1c1ccc(F)cc1,,,CHEMBL4396891,Eur J Med Chem,2019,,CHEMBL1138,EZETIMIBE,CHEMBL1138,4.88,0,http://www.openphacts.org/units/Nanomolar,3210875,=,1,1,=,,IC50,nM,,13070.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,,13.07
# ,,19440701,[],CHEMBL4431626,Antiviral activity against Dengue virus 3 infected in human Huh7 cells assessed as reduction in viral replication after 48 hrs by plaque assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)O[C@H]1C[C@H](O[C@H]2[C@@H](O)C[C@H](O[C@H]3[C@@H](O)C[C@H](O[C@H]4CC[C@@]5(C)[C@H](CC[C@@H]6[C@@H]5C[C@@H](O)[C@]5(C)[C@@H](C7=CC(=O)OC7)CC[C@]65O)C4)O[C@@H]3C)O[C@@H]2C)O[C@H](C)[C@H]1O[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O,,,CHEMBL4431301,J Med Chem,2016,,CHEMBL506569,LANATOSIDE C,CHEMBL506569,6.30,0,http://www.openphacts.org/units/Nanomolar,3247495,=,1,1,=,,IC50,nM,,500.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,1.0,0.5
# ,,24708214,"[{'comments': None, 'relation': '=', 'result_flag': 0, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'TIME', 'standard_units': 'hr', 'standard_value': '0.75', 'text_value': None, 'type': 'Time', 'units': 'min', 'value': '45.0'}]",CHEMBL5109272,Antiviral activity against DENV3 infected in African green monkey Vero cells assessed as inhibition of virus induced cytopathic effect incubated for 45 mins by focus-formation assay,F,,,BAO_0000190,BAO_0000218,organism-based format,FC(F)(F)Oc1cccc(Nc2ccnc(Nc3cccc(OC(F)(F)F)c3)n2)c1,,,CHEMBL5107980,Eur J Med Chem,2022,,CHEMBL5176406,,CHEMBL5176406,5.30,0,http://www.openphacts.org/units/Nanomolar,3853114,=,1,1,=,,IC50,nM,,5000.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,,5.0
# ,,24789044,"[{'comments': None, 'relation': '=', 'result_flag': 0, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'TIME', 'standard_units': 'hr', 'standard_value': '144.0', 'text_value': None, 'type': 'Time', 'units': 'day', 'value': '6.0'}]",CHEMBL5131959,Antiviral activity against DENV 3 infected in african green monkey Vero cells assessed as focus formation measured after 6 days,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1cccc(-c2cc(Nc3ccc(OC(F)(F)F)cc3)ncn2)c1,,,CHEMBL5131376,J Med Chem,2022,,CHEMBL5182661,,CHEMBL5182661,5.30,0,http://www.openphacts.org/units/Nanomolar,3869497,=,1,1,=,,IC50,nM,,5000.0,CHEMBL612717,dengue virus type 3,dengue virus type 3,11069,,,IC50,uM,UO_0000065,,5.0

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#   action_type activity_comment  activity_id  \
# 0        None             None     12674455
# 1        None             None     18326333
# 2        None             None     19235373
# 3        None             None     19235452
# 4        None             None     19235453
# 5        None             None     19235470
# 6        None             None     19440701
# 7        None             None     24708214
# 8        None             None     24789044
# 9        None             None     24866747
#
#                                  activity_properties assay_chembl_id  \
# 0                                                 []   CHEMBL2341562
# 1                                                 []   CHEMBL4135359
# 2                                                 []   CHEMBL4398331
# 3                                                 []   CHEMBL4398397
# 4                                                 []   CHEMBL4398397
# 5                                                 []   CHEMBL4398414
# 6                                                 []   CHEMBL4431626
# 7  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5109272
# 8  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5131959
# 9  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5151807
#
#                                    assay_description assay_type  \
# 0  Antiviral activity against Dengue virus 3 stra...          F
# 1  Antiviral activity against Fluc-tagged DENV3 i...          F
# 2  Antiviral activity against DENV3 Bolivia infec...          F
# 3  Antiviral activity against DENV3 97 infected i...          F
# 4  Antiviral activity against DENV3 97 infected i...          F
# 5  Antiviral activity against DENV3 infected in h...          F
# 6  Antiviral activity against Dengue virus 3 infe...          F
# 7  Antiviral activity against DENV3 infected in A...          F
# 8  Antiviral activity against DENV 3 infected in ...          F
# 9  Antiviral activity against DENV-3 infected ham...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
# 3                    None                   None  BAO_0000190  ...
# 4                    None                   None  BAO_0000190  ...
# 5                    None                   None  BAO_0000190  ...
# 6                    None                   None  BAO_0000190  ...
# 7                    None                   None  BAO_0000190  ...
# 8                    None                   None  BAO_0000190  ...
# 9                    None                   None  BAO_0000190  ...
#
#        target_organism     target_pref_name target_tax_id text_value  toid  \
# 0  dengue virus type 3  dengue virus type 3         11069       None  None
# 1  dengue virus type 3  dengue virus type 3         11069       None  None
# 2  dengue virus type 3  dengue virus type 3         11069       None  None
# 3  dengue virus type 3  dengue virus type 3         11069       None  None
# 4  dengue virus type 3  dengue virus type 3         11069       None  None
# 5  dengue virus type 3  dengue virus type 3         11069       None  None
# 6  dengue virus type 3  dengue virus type 3         11069       None  None
# 7  dengue virus type 3  dengue virus type 3         11069       None  None
# 8  dengue virus type 3  dengue virus type 3         11069       None  None
# 9  dengue virus type 3  dengue virus type 3         11069       None  None
#
#    type units    uo_units upper_value  value
# 0  IC50    uM  UO_0000065        None  100.0
# 1  IC50    uM  UO_0000065        None   0.73
# 2  IC50    uM  UO_0000065        15.0    6.8
# 3  IC50    uM  UO_0000065        10.4    6.9
# 4  IC50    uM  UO_0000065        10.8    6.5
# 5  IC50    uM  UO_0000065        None  13.07
# 6  IC50    uM  UO_0000065         1.0    0.5
# 7  IC50    uM  UO_0000065        None    5.0
# 8  IC50    uM  UO_0000065        None    5.0
# 9  IC50    uM  UO_0000065        None   1.66
#
# [10 rows x 46 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL2332247    O=C(CNCc1ccc(C(=O)N2CCCCC2)cc1)NC(=O)COc1ccccc1
# 1      CHEMBL4175102  COc1ccc(-c2cc(-c3ccc4cc(F)ccc4n3)n(-c3ccc(S(N)...
# 2      CHEMBL4526128  O=C(N[C@@H](Cc1ccc(O)cc1)C(=O)O)c1cc(-c2ccccc2...
# 3      CHEMBL4443913  CCCCCCCCCCCCNCCNC(=O)C[C@@]1(O)C[C@@H](O)[C@@H...
# 4      CHEMBL4572441  CCCCCCCCCCCCCCNCCNC(=O)C[C@]1(O)C[C@@H](O)[C@@...
# 5         CHEMBL1138  O=C1[C@H](CC[C@H](O)c2ccc(F)cc2)[C@@H](c2ccc(O...
# 6       CHEMBL506569  CC(=O)O[C@H]1C[C@H](O[C@H]2[C@@H](O)C[C@H](O[C...
# 7      CHEMBL5176406  FC(F)(F)Oc1cccc(Nc2ccnc(Nc3cccc(OC(F)(F)F)c3)n...
# 8      CHEMBL5182661    CC(=O)c1cccc(-c2cc(Nc3ccc(OC(F)(F)F)cc3)ncn2)c1
# 9       CHEMBL263291  CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@...
#
#   bioactivity_class standard_value
# 0          inactive       100000.0
# 1            active          730.0
# 2      intermediate         6800.0
# 3      intermediate         6900.0
# 4      intermediate         6500.0
# 5          inactive        13070.0
# 6            active          500.0
# 7      intermediate         5000.0
# 8      intermediate         5000.0
# 9      intermediate         1660.0

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL2332247    O=C(CNCc1ccc(C(=O)N2CCCCC2)cc1)NC(=O)COc1ccccc1
# 1      CHEMBL4175102  COc1ccc(-c2cc(-c3ccc4cc(F)ccc4n3)n(-c3ccc(S(N)...
# 2      CHEMBL4526128  O=C(N[C@@H](Cc1ccc(O)cc1)C(=O)O)c1cc(-c2ccccc2...
# 3      CHEMBL4443913  CCCCCCCCCCCCNCCNC(=O)C[C@@]1(O)C[C@@H](O)[C@@H...
# 4      CHEMBL4572441  CCCCCCCCCCCCCCNCCNC(=O)C[C@]1(O)C[C@@H](O)[C@@...
# 5         CHEMBL1138  O=C1[C@H](CC[C@H](O)c2ccc(F)cc2)[C@@H](c2ccc(O...
# 6       CHEMBL506569  CC(=O)O[C@H]1C[C@H](O[C@H]2[C@@H](O)C[C@H](O[C...
# 7      CHEMBL5176406  FC(F)(F)Oc1cccc(Nc2ccnc(Nc3cccc(OC(F)(F)F)c3)n...
# 8      CHEMBL5182661    CC(=O)c1cccc(-c2cc(Nc3ccc(OC(F)(F)F)cc3)ncn2)c1
# 9       CHEMBL263291  CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@...
#
#   standard_value
# 0       100000.0
# 1          730.0
# 2         6800.0
# 3         6900.0
# 4         6500.0
# 5        13070.0
# 6          500.0
# 7         5000.0
# 8         5000.0
# 9         1660.0

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL2332247    O=C(CNCc1ccc(C(=O)N2CCCCC2)cc1)NC(=O)COc1ccccc1
# 1      CHEMBL4175102  COc1ccc(-c2cc(-c3ccc4cc(F)ccc4n3)n(-c3ccc(S(N)...
# 2      CHEMBL4526128  O=C(N[C@@H](Cc1ccc(O)cc1)C(=O)O)c1cc(-c2ccccc2...
# 3      CHEMBL4443913  CCCCCCCCCCCCNCCNC(=O)C[C@@]1(O)C[C@@H](O)[C@@H...
# 4      CHEMBL4572441  CCCCCCCCCCCCCCNCCNC(=O)C[C@]1(O)C[C@@H](O)[C@@...
# 5         CHEMBL1138  O=C1[C@H](CC[C@H](O)c2ccc(F)cc2)[C@@H](c2ccc(O...
# 6       CHEMBL506569  CC(=O)O[C@H]1C[C@H](O[C@H]2[C@@H](O)C[C@H](O[C...
# 7      CHEMBL5176406  FC(F)(F)Oc1cccc(Nc2ccnc(Nc3cccc(OC(F)(F)F)c3)n...
# 8      CHEMBL5182661    CC(=O)c1cccc(-c2cc(Nc3ccc(OC(F)(F)F)cc3)ncn2)c1
# 9       CHEMBL263291  CC[C@H](C)[C@H]1O[C@]2(CC[C@@H]1C)C[C@@H]1C[C@...
#
#   standard_value             0
# 0       100000.0      inactive
# 1          730.0        active
# 2         6800.0  intermediate
# 3         6900.0  intermediate
# 4         6500.0  intermediate
# 5        13070.0      inactive
# 6          500.0        active
# 7         5000.0  intermediate
# 8         5000.0  intermediate
# 9         1660.0  intermediate

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 6768 Nov 24 13:03 bioactivity_data.csv
# -rw-r--r-- 1 root root 1184 Nov 24 13:21 bioactivity_preprocessed_data.csv
# drwx------ 6 root root 4096 Nov 24 13:06 gdrive
# drwxr-xr-x 1 root root 4096 Nov 21 14:25 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %%
ls -1
# Out:
# bioactivity_data.csv
# bioactivity_preprocessed_data.csv
# gdrive/
# sample_data/

# %% [markdown]
# ---
