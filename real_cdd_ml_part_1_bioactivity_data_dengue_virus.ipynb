# %% [markdown]
# <a href="https://colab.research.google.com/github/aghnisyaa/bioactivity_project/blob/main/real_cdd_ml_part_1_bioactivity_data_dengue_virus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
#
# In this Jupyter notebook, I will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 763.6 kB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 1.7 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.2 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for dengue virus**

# %%
# Target search for dengue virus
target = new_client.target
target_query = target.search('dengue virus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 197                                                 []
# 198  [{'xref_id': 'Q69422', 'xref_name': None, 'xre...
# 199                                                 []
# 200                                                 []
# 201                                                 []
#
#                                               organism  \
# 0                                         Dengue virus
# 1                                  dengue virus type 4
# 2                                  dengue virus type 1
# 3                                  dengue virus type 2
# 4                                  dengue virus type 3
# ..                                                 ...
# 197  Human immunodeficiency virus type 1 (RF/HAT IS...
# 198                               Hepatitis GB virus B
# 199                                       Homo sapiens
# 200                                       Homo sapiens
# 201                                       Homo sapiens
#
#                                              pref_name  score  \
# 0                                         Dengue virus   24.0
# 1                                  dengue virus type 4   18.0
# 2                                  dengue virus type 1   18.0
# 3                                  dengue virus type 2   18.0
# 4                                  dengue virus type 3   18.0
# ..                                                 ...    ...
# 197  Human immunodeficiency virus type 1 (RF/HAT IS...    4.0
# 198  Hepatitis GB virus B NS5B RNA-dependent RNA po...    4.0
# 199    VEGF-receptor 2 and tyrosine-protein kinase SRC    4.0
# 200                                Sharpin/RBCK1/RNF31    4.0
# 201                                       80S Ribosome    0.0
#
#      species_group_flag target_chembl_id  \
# 0                 False     CHEMBL613757
# 1                 False     CHEMBL613728
# 2                 False     CHEMBL613360
# 3                 False     CHEMBL613966
# 4                 False     CHEMBL612717
# ..                  ...              ...
# 197               False     CHEMBL613498
# 198               False       CHEMBL5981
# 199               False    CHEMBL2111336
# 200               False    CHEMBL4296109
# 201               False    CHEMBL3987582
#
#                                      target_components  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 197                                                 []
# 198  [{'accession': 'Q69422', 'component_descriptio...
# 199  [{'accession': 'P12931', 'component_descriptio...
# 200  [{'accession': 'Q9H0F6', 'component_descriptio...
# 201  [{'accession': 'P08865', 'component_descriptio...
#
#                       target_type  tax_id
# 0                        ORGANISM   12637
# 1                        ORGANISM   11070
# 2                        ORGANISM   11053
# 3                        ORGANISM   11060
# 4                        ORGANISM   11069
# ..                            ...     ...
# 197                      ORGANISM   11701
# 198                SINGLE PROTEIN   39113
# 199             SELECTIVITY GROUP    9606
# 200               PROTEIN COMPLEX    9606
# 201  PROTEIN NUCLEIC-ACID COMPLEX    9606
#
# [202 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for dengue virus**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL613757'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None      2927199                  []
# 1         None             None      2927200                  []
# 2         None             None      2927201                  []
# 3         None             None      2927202                  []
# 4         None             None      2927203                  []
# ..         ...              ...          ...                 ...
# 73        None             None     24788933                  []
# 74        None             None     24866694                  []
# 75        None             None     24866695                  []
# 76        None             None     24866696                  []
# 77        None             None     24866697                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1041197            Antiviral activity against Dengue virus
# 1    CHEMBL1041197            Antiviral activity against Dengue virus
# 2    CHEMBL1041197            Antiviral activity against Dengue virus
# 3    CHEMBL1041197            Antiviral activity against Dengue virus
# 4    CHEMBL1041197            Antiviral activity against Dengue virus
# ..             ...                                                ...
# 73   CHEMBL5131874                    Antiviral activity against DENV
# 74   CHEMBL5151773  Antiviral activity against DENV NS5/RNA-depend...
# 75   CHEMBL5151773  Antiviral activity against DENV NS5/RNA-depend...
# 76   CHEMBL5151773  Antiviral activity against DENV NS5/RNA-depend...
# 77   CHEMBL5151773  Antiviral activity against DENV NS5/RNA-depend...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           F                    None                   None  BAO_0000190
# 1           F                    None                   None  BAO_0000190
# 2           F                    None                   None  BAO_0000190
# 3           F                    None                   None  BAO_0000190
# 4           F                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 73          F                    None                   None  BAO_0000190
# 74          F                    None                   None  BAO_0000190
# 75          F                    None                   None  BAO_0000190
# 76          F                    None                   None  BAO_0000190
# 77          F                    None                   None  BAO_0000190
#
#     ... target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 1   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 2   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 3   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 4   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# ..  ...             ...              ...           ...        ...   ...   ...
# 73  ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 74  ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 75  ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 76  ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 77  ...    Dengue virus     Dengue virus         12637       None  None  IC50
#
#    units    uo_units upper_value  value
# 0     mM  UO_0000065        None    2.0
# 1     mM  UO_0000065        None    2.0
# 2     mM  UO_0000065        None    2.0
# 3     uM  UO_0000065        None  294.0
# 4     uM  UO_0000065        None   46.0
# ..   ...         ...         ...    ...
# 73    uM  UO_0000065        None   0.96
# 74    uM  UO_0000065        None    2.5
# 75    uM  UO_0000065        None    2.7
# 76    uM  UO_0000065        None    2.2
# 77    uM  UO_0000065        None    2.7
#
# [78 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google drive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !ls "/content/gdrive/My Drive/"
# Out:
# 'Colab Notebooks'

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 55
# -rw------- 1 root root 41497 Nov 30 02:11 bioactivity_data.csv
# -rw------- 1 root root  6890 Nov 25 10:45 bioactivity_data_preprocessed_new.csv
# -rw------- 1 root root  6153 Nov 25 10:37 bioactivity_preprocessed_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,2927199,[],CHEMBL1041197,Antiviral activity against Dengue virus,F,,,BAO_0000190,BAO_0000218,organism-based format,O=C(O)/C=C/c1ccc(OS(=O)(=O)O)cc1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1155220,J Med Chem,2009.0,,CHEMBL575429,,CHEMBL575429,,0,http://www.openphacts.org/units/Nanomolar,851128,=,1,1,=,,IC50,nM,,2000000.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,mM,UO_0000065,,2.0
# ,,2927200,[],CHEMBL1041197,Antiviral activity against Dengue virus,F,,,BAO_0000190,BAO_0000218,organism-based format,CN(CCCNC(=O)c1ccc(O)cc1)CCCNC(=O)c1ccc(O)cc1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1155220,J Med Chem,2009.0,,CHEMBL574855,,CHEMBL574855,,0,http://www.openphacts.org/units/Nanomolar,851395,=,1,1,=,,IC50,nM,,2000000.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,mM,UO_0000065,,2.0
# ,,2927201,[],CHEMBL1041197,Antiviral activity against Dengue virus,F,,,BAO_0000190,BAO_0000218,organism-based format,CCN(CCCN(CC)C(=O)c1ccc(O)cc1)C(=O)c1ccc(O)cc1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1155220,J Med Chem,2009.0,,CHEMBL574190,,CHEMBL574190,,0,http://www.openphacts.org/units/Nanomolar,851378,=,1,1,=,,IC50,nM,,2000000.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,mM,UO_0000065,,2.0
# ,,2927202,[],CHEMBL1041197,Antiviral activity against Dengue virus,F,,,BAO_0000190,BAO_0000218,organism-based format,CN(CCCNC(=O)c1ccc(O)cc1)CCCNC(=O)c1ccc2cc(O)ccc2c1,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1155220,J Med Chem,2009.0,,CHEMBL575724,,CHEMBL575724,,0,http://www.openphacts.org/units/Nanomolar,851418,=,1,1,=,,IC50,nM,,294000.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,uM,UO_0000065,,294.0
# ,,2927203,[],CHEMBL1041197,Antiviral activity against Dengue virus,F,,,BAO_0000190,BAO_0000218,organism-based format,CCN(CCOC(=O)/C=C/c1ccc(O)cc1)Cc1cc(Cl)ccc1O,,,CHEMBL1155220,J Med Chem,2009.0,,CHEMBL582943,,CHEMBL582943,4.34,0,http://www.openphacts.org/units/Nanomolar,851444,=,1,1,=,,IC50,nM,,46000.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,uM,UO_0000065,,46.0
# ,,2927210,[],CHEMBL1041197,Antiviral activity against Dengue virus,F,,,BAO_0000190,BAO_0000218,organism-based format,COc1cc(NC(=O)Nc2cccc(CNC(=O)O[C@H]3CCOC3)c2)ccc1-c1cnco1,,,CHEMBL1155220,J Med Chem,2009.0,,CHEMBL304087,MERIMEPODIB,CHEMBL304087,5.10,0,http://www.openphacts.org/units/Nanomolar,851331,=,1,1,=,,IC50,nM,,8000.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,uM,UO_0000065,,8.0
# ,,2927214,[],CHEMBL1041197,Antiviral activity against Dengue virus,F,,,BAO_0000190,BAO_0000218,organism-based format,O[C@H]1[C@H](O)[C@@H](O)CN2CC[C@H](O)[C@H]12,,,CHEMBL1155220,J Med Chem,2009.0,,CHEMBL311226,CASTANOSPERMINE,CHEMBL311226,6.00,0,http://www.openphacts.org/units/Nanomolar,851457,=,1,1,=,,IC50,nM,,1000.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,uM,UO_0000065,,1.0
# ,,15139706,[],CHEMBL3384587,Antiviral activity against Dengue virus assessed as inhibition of viral replication,F,,,BAO_0000190,BAO_0000218,organism-based format,C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](Oc3c(-c4ccc(O)c(O)c4)oc4cc(O)cc(O)c4c3=O)[C@H](O)[C@@H](O)[C@@H]2O)[C@H](O)[C@H](O)[C@H]1O,,,CHEMBL3352310,Eur J Med Chem,2014.0,,CHEMBL226335,RUTIN,CHEMBL226335,5.77,0,http://www.openphacts.org/units/Nanomolar,2241357,=,1,1,=,,IC50,nM,,1700.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,uM,UO_0000065,,1.7
# ,,15139707,[],CHEMBL3384587,Antiviral activity against Dengue virus assessed as inhibition of viral replication,F,,,BAO_0000190,BAO_0000218,organism-based format,O=c1c(OC2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)c(-c2ccc(OC3O[C@H](CO)[C@@H](O)[C@H](O)[C@H]3O)c(O)c2)oc2cc(O)cc(O)c12,,,CHEMBL3352310,Eur J Med Chem,2014.0,,CHEMBL3344315,,CHEMBL3344315,5.77,0,http://www.openphacts.org/units/Nanomolar,2241356,=,1,1,=,,IC50,nM,,1700.0,CHEMBL613757,Dengue virus,Dengue virus,12637,,,IC50,uM,UO_0000065,,1.7

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None      2927199                  []
# 1         None             None      2927200                  []
# 2         None             None      2927201                  []
# 3         None             None      2927202                  []
# 4         None             None      2927203                  []
# ..         ...              ...          ...                 ...
# 73        None             None     24788933                  []
# 74        None             None     24866694                  []
# 75        None             None     24866695                  []
# 76        None             None     24866696                  []
# 77        None             None     24866697                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1041197            Antiviral activity against Dengue virus
# 1    CHEMBL1041197            Antiviral activity against Dengue virus
# 2    CHEMBL1041197            Antiviral activity against Dengue virus
# 3    CHEMBL1041197            Antiviral activity against Dengue virus
# 4    CHEMBL1041197            Antiviral activity against Dengue virus
# ..             ...                                                ...
# 73   CHEMBL5131874                    Antiviral activity against DENV
# 74   CHEMBL5151773  Antiviral activity against DENV NS5/RNA-depend...
# 75   CHEMBL5151773  Antiviral activity against DENV NS5/RNA-depend...
# 76   CHEMBL5151773  Antiviral activity against DENV NS5/RNA-depend...
# 77   CHEMBL5151773  Antiviral activity against DENV NS5/RNA-depend...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           F                    None                   None  BAO_0000190
# 1           F                    None                   None  BAO_0000190
# 2           F                    None                   None  BAO_0000190
# 3           F                    None                   None  BAO_0000190
# 4           F                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 73          F                    None                   None  BAO_0000190
# 74          F                    None                   None  BAO_0000190
# 75          F                    None                   None  BAO_0000190
# 76          F                    None                   None  BAO_0000190
# 77          F                    None                   None  BAO_0000190
#
#     ... target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 1   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 2   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 3   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 4   ...    Dengue virus     Dengue virus         12637       None  None  IC50
# ..  ...             ...              ...           ...        ...   ...   ...
# 73  ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 74  ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 75  ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 76  ...    Dengue virus     Dengue virus         12637       None  None  IC50
# 77  ...    Dengue virus     Dengue virus         12637       None  None  IC50
#
#    units    uo_units upper_value  value
# 0     mM  UO_0000065        None    2.0
# 1     mM  UO_0000065        None    2.0
# 2     mM  UO_0000065        None    2.0
# 3     uM  UO_0000065        None  294.0
# 4     uM  UO_0000065        None   46.0
# ..   ...         ...         ...    ...
# 73    uM  UO_0000065        None   0.96
# 74    uM  UO_0000065        None    2.5
# 75    uM  UO_0000065        None    2.7
# 76    uM  UO_0000065        None    2.2
# 77    uM  UO_0000065        None    2.7
#
# [69 rows x 46 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL575429                   O=C(O)/C=C/c1ccc(OS(=O)(=O)O)cc1
# 1        CHEMBL574855       CN(CCCNC(=O)c1ccc(O)cc1)CCCNC(=O)c1ccc(O)cc1
# 2        CHEMBL574190      CCN(CCCN(CC)C(=O)c1ccc(O)cc1)C(=O)c1ccc(O)cc1
# 3        CHEMBL575724  CN(CCCNC(=O)c1ccc(O)cc1)CCCNC(=O)c1ccc2cc(O)cc...
# 4        CHEMBL582943        CCN(CCOC(=O)/C=C/c1ccc(O)cc1)Cc1cc(Cl)ccc1O
# ..                ...                                                ...
# 64       CHEMBL495739   Cl.O=S(=O)(NCCNC/C=C/c1ccc(Br)cc1)c1cccc2cnccc12
# 65      CHEMBL5170343                        O=C(O)/C=C/C#CCCCCCCCC(=O)O
# 66       CHEMBL251279                         CCCCC#CC#CC#CCCCCCCCC(=O)O
# 67      CHEMBL2204412                       CCCC/C=C/C#CC#CCCCCCCCC(=O)O
# 68      CHEMBL5209026                          CCCC/C=C/C#CCCCCCCCC(=O)O
#
#    bioactivity_class standard_value
# 0           inactive      2000000.0
# 1           inactive      2000000.0
# 2           inactive      2000000.0
# 3           inactive       294000.0
# 4           inactive        46000.0
# ..               ...            ...
# 64            active          960.0
# 65      intermediate         2500.0
# 66      intermediate         2700.0
# 67      intermediate         2200.0
# 68      intermediate         2700.0
#
# [69 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 60
# -rw-r--r-- 1 root root 41497 Nov 30 02:10 bioactivity_data.csv
# -rw-r--r-- 1 root root  6835 Nov 30 02:20 bioactivity_preprocessed_data.csv
# drwx------ 6 root root  4096 Nov 30 02:10 gdrive
# drwxr-xr-x 1 root root  4096 Nov 25 19:13 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_data_preprocessed_new.csv  bioactivity_preprocessed_data.csv

# %%
ls -1
# Out:
# bioactivity_data.csv
# bioactivity_preprocessed_data.csv
# gdrive/
# sample_data/

# %% [markdown]
# ---
